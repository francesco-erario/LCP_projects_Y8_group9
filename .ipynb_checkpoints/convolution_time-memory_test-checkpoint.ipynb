# %%
import numpy as np
import scipy.signal as scs
import matplotlib.pyplot as plt
import time # library to measure time
import tracemalloc # library to measure memory usage
import pandas as pd

np.random.seed(42) # set fixed seed

# %%
def evolution(world, neighbours):
    new_world = np.zeros_like(world)
    # condition1 = ( neighbours < 2 ) useless, we start from a 0's new world ——> dead
    # condition2 = ( neighbours > 3 ) ——> dead
    # condition3 = ( neighbours == 2 ) | ( neighbours == 3 ) # '|' is bitwise 'or' ——> alive only if already alive
    # condition4 = ( neighbours == 3 ) ——> become alive if dead
    survive = ( world == 1 ) & ( neighbours == 2 ) # does not need the 3 ——> always alive
    born = ( neighbours == 3 )
    
    new_world[survive | born] = 1

    return new_world

# %%
size_list = [10, 30, 100, 150, 330, 640, 1000, 1500, 3000]

data = []

for N in size_list:

    tracemalloc.start()
    start_time = time.time()

    # Initialize the world at random
    world = np.random.randint(0,2, size=(N,N))
    kernel = np.ones(shape=(3,3))
    kernel[1,1] = 0 # Central value does not count in the convolution

    # Temporary cycle
    T = 10
    for t in range(T):
        convolution = scs.convolve2d(world, kernel, mode='same', boundary='wrap')
        world = evolution(world, convolution)


    end_time = time.time()
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()

    data.append({
        'N': N,
        'time_s': end_time - start_time,
        'current_kB': current / 1024,
        'peak_kB': peak / 1024
    })

    print(f"——— Iteration: {size_list.index(N)} –––")
    print(f"Time elapsed: {end_time - start_time:.5f} s")
    print(f"Current memory: {current / 1024:.5f} kB")
    print(f"Peak memory: {peak / 1024:.5f} kB")
    print("\n")

df = pd.DataFrame(data)
df.to_csv('convolution_TM_data.csv', index=False)
# Out:
# ——— Iteration: 0 –––
# Time elapsed: 0.00075 s
# Current memory: 2.38281 kB
# Peak memory: 4.28516 kB
#
#
# ——— Iteration: 1 –––
# Time elapsed: 0.00211 s
# Current memory: 17.74707 kB
# Peak memory: 32.48340 kB
#
#
# ——— Iteration: 2 –––
# Time elapsed: 0.00479 s
# Current memory: 157.02637 kB
# Peak memory: 313.60449 kB
#
#
# ——— Iteration: 3 –––
# Time elapsed: 0.00911 s
# Current memory: 351.91406 kB
# Peak memory: 703.80469 kB
#
#
# ——— Iteration: 4 –––
# Time elapsed: 0.05388 s
# Current memory: 1701.91406 kB
# Peak memory: 3403.80469 kB
#
#
# ——— Iteration: 5 –––
# Time elapsed: 0.11008 s
# Current memory: 6400.35156 kB
# Peak memory: 12800.67969 kB
#
#
# ——— Iteration: 6 –––
# Time elapsed: 0.26448 s
# Current memory: 15626.28906 kB
# Peak memory: 31251.61719 kB
#
#
# ——— Iteration: 7 –––
# Time elapsed: 0.59128 s
# Current memory: 35157.45801 kB
# Peak memory: 70314.03613 kB
#
#
# ——— Iteration: 8 –––
# Time elapsed: 2.38462 s
# Current memory: 140626.23340 kB
# Peak memory: 281251.56152 kB
